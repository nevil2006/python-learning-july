# %%
data = {
    'Name': ['John', 'Doe', 'Alice'],
    'Age': [45, 55, 65]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age
# 0   John   45
# 1    Doe   55
# 2  Alice   65

# %%
loc={
    'rollnumber':[60,61,62],
    'age' :[23,24,25],
    'mathsmark' :[19,20,21]
}

# %%
lb=pd.DataFrame(loc)

# %%
lb
# Out:
#    rollnumber  age  mathsmark
# 0          60   23         19
# 1          61   24         20
# 2          62   25         21
