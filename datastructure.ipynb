# %% [markdown]
# build in data structures in python?

# %% [markdown]
# data structure in python
#
# 1.list
# 2.sets
# 3.tuples
# 4.dictionary

# %% [markdown]
# 1.List

# %%
empty_bag=[]

# %%
empty_bag
# Out:
# []

# %%
type(empty_bag)
# Out:
# list

# %%
items_to_buy=["wine","juice","cake","wine"]
items_to_buy
# Out:
# ['wine', 'juice', 'cake', 'wine']

# %%
items_to_buy[0]
# Out:
# 'wine'

# %%
len(items_to_buy)
# Out:
# 4

# %%
items_to_buy[-1]
# Out:
# 'wine'

# %%
items_to_buy[1:4]
# Out:
# ['juice', 'cake', 'wine']

# %%
items_to_buy[1]="bread"
items_to_buy
# Out:
# ['wine', 'bread', 'cake', 'wine']
