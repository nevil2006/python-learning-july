# %% [markdown]
# build in data structures in python?

# %% [markdown]
# data structure in python
#
# 1.list
# 2.sets
# 3.tuples
# 4.dictionary

# %% [markdown]
# 1.List

# %%
empty_bag=[]

# %%
empty_bag
# Out:
# []

# %%
type(empty_bag)
# Out:
# list

# %%
items_to_buy=["wine","juice","cake","wine"]
items_to_buy
# Out:
# ['wine', 'juice', 'cake', 'wine']

# %%
items_to_buy[0]
# Out:
# 'wine'

# %%
len(items_to_buy)
# Out:
# 4

# %%
items_to_buy[-1]
# Out:
# 'wine'

# %%
items_to_buy[1:4]
# Out:
# ['juice', 'cake', 'wine']

# %%
items_to_buy[1]="bread"
items_to_buy
# Out:
# ['wine', 'bread', 'cake', 'wine']

# %% [markdown]
# sets

# %%
empty_cover=set()

# %%
empty_cover
# Out:
# set()

# %%
empty_cover={"apple","banana","orange","apple"}
empty_cover
# Out:
# {'apple', 'banana', 'orange'}

# %%
type(empty_cover)
# Out:
# set

# %%
empty_cover={"apple","banana","orange","apple",0,7.9,True}

# %%
empty_cover
# Out:
# {0, 7.9, True, 'apple', 'banana', 'orange'}

# %% [markdown]
# it convert set into list

# %%
empty_cover={"apple","banana","orange","apple",0,7.9,True}
s=list(empty_cover)
print(s[0])
print(s[1])
print(s[-1])
# Out:
# 0
# apple
# orange

# %%
empty_cover
# Out:
# {0, 7.9, True, 'apple', 'banana', 'orange'}

# %%
empty_cover.add("watermelon")

# %%
empty_cover
# Out:
# {0, 7.9, True, 'apple', 'banana', 'orange', 'watermelon'}

# %%
empty_cover.discard("banana")

# %%
empty_cover
# Out:
# {0, 7.9, True, 'apple', 'orange', 'watermelon'}

# %%
empty_cover.clear()
empty_cover
# Out:
# set()

# %%
empty_cover={"apple","banana","orange","apple",0,7.9,True}
empty_cover
# Out:
# {0, 7.9, True, 'apple', 'banana', 'orange'}

# %%
c = empty_cover.copy()

# %%
c
# Out:
# {0, 7.9, True, 'apple', 'banana', 'orange'}

# %%
a={"apple","banana","orange","apple",0,7.9,True}
b={"banana","kiwi",0,3.5,False}
s=a.difference(b)
t=b.difference(a)

# %%
s
# Out:
# {7.9, True, 'apple', 'orange'}

# %%
t
# Out:
# {3.5, 'kiwi'}

# %%
p=a.intersection(b)
p
# Out:
# {0, 'banana'}

# %%
a.isdisjoint(b)
# Out:
# False

# %%
{1,2}.issubset({45,3,4})
# Out:
# False

# %%
x = a.pop()

# %%
x
# Out:
# 0

# %%
empty_cover
# Out:
# {0, 7.9, True, 'apple', 'banana', 'orange'}

# %%
s = {"apple", "banana", "apple", "orange"}
print(s)
# Out:
# {'apple', 'banana', 'orange'}

# %%
s = ["apple", "banana", "apple", "orange"]
print(type(s))
# Out:
# <class 'list'>

# %%
s = {"apple", "banana", "apple", "orange","apple"}
print(len(s))
print(type(s))
# Out:
# 3
# <class 'set'>

# %% [markdown]
# TUPLES

# %%
words=["hello","world","hello","python","code","world"]
words=set(words)

# %%
print(type(words))
# Out:
# <class 'tuple'>

# %%
word=(1,20.9,"hello","true","hello")
word
# Out:
# (1, 20.9, 'hello', 'true', 'hello')

# %%
words=("hello","world","hello","python","code","world")
words
print(type(words))
# Out:
# <class 'tuple'>

# %%
print(words[1:4])
# Out:
# ('world', 'hello', 'python')

# %%
words.count("hello")
# Out:
# 2

# %% [markdown]
# dictionary
# it is key value pair

# %%
dict={"alice":25,"bob":30,"carol":222}
dict
# Out:
# {'alice': 25, 'bob': 30, 'carol': 222}

# %%
type(dict)
# Out:
# dict

# %%
student={89,98,76}
student
# Out:
# {76, 89, 98}

# %%
type(student)
# Out:
# set
