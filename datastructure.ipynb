# %% [markdown]
# build in data structures in python?

# %% [markdown]
# data structure in python
#
# 1.list
# 2.sets
# 3.tuples
# 4.dictionary

# %% [markdown]
# 1.List

# %%
empty_bag=[]

# %%
empty_bag
# Out:
# []

# %%
type(empty_bag)
# Out:
# list
